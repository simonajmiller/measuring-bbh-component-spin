# %%
import json
import glob
import matplotlib.pylab as plt
import numpy as np
from scipy.special import erf
import sys
sys.path.append('./../../Figures/')
import makeCorner
from fig_helper_functions import draw_chiEffs_and_chiPs_betaDoubleGauss
from scipy.stats import gaussian_kde

sys.path.append('./../../Code/PopulationInference')
from posterior_helper_functions import *

# %% [markdown]
# Load `.json` result files which contains
# 1. direct output from `emcee` interference, without any processing
# 2. post-processed output from `emcee` inference
#
# and make dict containing info for all populations under the given model

# %%
# For loading files
model = 'betaPlusDoubleGaussian2'
pops = ['1', '2', '3']
seeds = ['0', '492', '526', '738', '847', '929']
nevent = '70'
# Make Dict
data_dict = {}

# Cycle through the different populations and no. of events
for pop in pops: 
    data_pop = {}
    for seed in seeds: 
        
        print(pop, seed)
        
        if seed=='0':
            name = f"103023_{model}_pop{pop}_{nevent}events"
        else: 
            name = f"103123_{model}_pop{pop}_{nevent}events_seed{seed}"
        
        with open(f'{model}/{name}.json', 'r') as f:
            data = json.load(f)
            
        data_pop[seed] = data    
            
    data_dict['pop '+pop] = data_pop
# Out:
# 1 0
# 1 492
# 1 526
# 1 738
# 1 847
# 1 929
# 2 0
# 2 492
# 2 526
# 2 738
# 2 847
# 2 929
# 3 0
# 3 492
# 3 526
# 3 738
# 3 847
# 3 929

# %%
# Names of populations from paper for plotting below
population_labels_dict = {
    'pop 1':r'$\mathrm{\textsc{HighSpinPrecessing}}$', 
    'pop 2':r'$\mathrm{\textsc{MediumSpin}}$', 
    'pop 3':r'$\mathrm{\textsc{LowSpinAligned}}$'
}

# Colors corresponding to different numbers of events
colors_dict = {
    s:f'C{i}' for i,s in enumerate(seeds)
}

# %% [markdown]
# Let's make a corner plot showing posteriors on our each set of parameters:

# %%
# True mu_chi, sigma_chi, mu1_cost, sigma1_cost, mu2_cost, sigma2_cost, f, Bq:
hyperparams = { 
    '1':[0.55, 0.26, 0.42, 0.75, 0.19, 0.18, 0.45, 0.96],  
    '2':[0.32, 0.16, 0.33, 0.64, 0.59, 0.40, 0.36, 0.96],
    '3':[0.19, 0.12, -0.98, 0.44, 0.98, 0.31, 0.26, 0.96]
}

# %%
import importlib
importlib.reload(makeCorner)

for pop in pops: 
    
    # Fetch data
    pop_key = 'pop '+pop
    event_key = nevent+' events'
    data = data_dict[pop_key]

    # Plot
    fig = plt.figure(figsize=(15,15))

    toPlot = {
        "mu_chi":{
            "data":{seed:{'posterior':data[seed]['mu_chi']['processed'], 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(0,1), "label":r"$\mu_\chi$", "true_val":hyperparams[pop][0]
        },
        "sigma_chi":{
            "data":{seed:{'posterior':data[seed]['sigma_chi']['processed'], 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(0.07,0.3), "label":r"$\sigma_\chi$", "true_val":hyperparams[pop][1]
        },
        "mu1_cost":{
            "data":{seed:{'posterior':data[seed]['mu1_cost']['processed'], 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(-1,1), "label":r"$\mu_{1, \cos \theta}$", "true_val":hyperparams[pop][2]
        },
        "sigma1_cost":{
            "data":{seed:{'posterior':data[seed]['sigma1_cost']['processed'], 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(0.16,0.8), "label":r"$\sigma_{1, \cos \theta}$", "true_val":hyperparams[pop][3] 
        }, 
         "mu2_cost":{
            "data":{seed:{'posterior':data[seed]['mu2_cost']['processed'], 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(-1,1), "label":r"$\mu_{2, \cos \theta}$" , "true_val":hyperparams[pop][4]
        },
        "sigma2_cost":{
            "data":{seed:{'posterior':data[seed]['sigma2_cost']['processed'], 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(0.16,0.8), "label":r"$\sigma_{2, \cos \theta}$" , "true_val":hyperparams[pop][5]
        }, 
         "MF_cost":{
            "data":{seed:{'posterior':data[seed]['MF_cost']['processed'], 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(0,0.5), "label":r"$f$" , "true_val":hyperparams[pop][6]
        },
        "Bq":{
            "data":{seed:{'posterior':data[seed]['Bq']['processed'], 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(-1.5,4), "label":r"$\beta_q$" , "true_val":hyperparams[pop][7]
        }, 
        "minNeff":{
            "data":{seed:{'posterior':np.log10(data[seed]['minNsamps']), 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(-0.5,2.5), "label":r"min $\log_{10}\,N_\mathrm{samps}$" 
        },
        "Neff_inj":{
            "data":{seed:{'posterior':np.log10(data[seed]['Neff']), 'color':colors_dict[seed]} for seed in seeds},
            "plot_bounds":(2.5,5), "label":r"$\log_{10}\,N_\mathrm{eff}$" 
        }, 
    }

    makeCorner.plot_corner(fig,toPlot)
    plt.suptitle(population_labels_dict[pop_key], fontsize=14)
    plt.tight_layout()
    plt.show()
# Out:
# /local/simona.miller/ipykernel_3713332/1393473596.py:59: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 57
#      12 fig = plt.figure(figsize=(15,15))
#      14 toPlot = {
#      15     "mu_chi":{
#      16         "data":{seed:{'posterior':data[seed]['mu_chi']['processed'], 'color':colors_dict[seed]} for seed in seeds},
#    (...)
#      54     },
#      55 }
# ---> 57 makeCorner.plot_corner(fig,toPlot)
#      58 plt.suptitle(population_labels_dict[pop_key], fontsize=14)
#      59 plt.tight_layout()
#
# File ~/measuring-bbh-component-spin/Data/PopulationInferenceOutput/./../../Figures/makeCorner.py:159, in plot_corner(fig, plot_data, hist_alpha, bins, labelsize, logscale, vmax, plot_titles)
#     147         ax.hexbin(
#     148             posterior1,posterior2,
#     149             cmap=cmap,mincnt=1,gridsize=bins,bins=hexscale,
#    (...)
#     155                     plot_data[k]['plot_bounds'][1]),
#     156         )
#     158         # Plot contours
# --> 159         sns.kdeplot(x=posterior1, y=posterior2,
#     160                     ax=ax, color=color,
#     161                     levels=[0.5, 0.95],
#     162                     fill=False,
#     163                     zorder=2)
#     165 if 'true_val' in plot_data[key].keys():
#     166     ax.axvline(plot_data[key]['true_val'], ls='--', color='k')
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/seaborn/distributions.py:1731, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1717     p.plot_univariate_density(
#    1718         multiple=multiple,
#    1719         common_norm=common_norm,
#    (...)
#    1726         **plot_kws,
#    1727     )
#    1729 else:
# -> 1731     p.plot_bivariate_density(
#    1732         common_norm=common_norm,
#    1733         fill=fill,
#    1734         levels=levels,
#    1735         thresh=thresh,
#    1736         legend=legend,
#    1737         color=color,
#    1738         warn_singular=warn_singular,
#    1739         cbar=cbar,
#    1740         cbar_ax=cbar_ax,
#    1741         cbar_kws=cbar_kws,
#    1742         estimate_kws=estimate_kws,
#    1743         **kwargs,
#    1744     )
#    1746 return ax
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/seaborn/distributions.py:1081, in _DistributionPlotter.plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1079 try:
#    1080     if not singular:
# -> 1081         density, support = estimator(*observations, weights=weights)
#    1082 except np.linalg.LinAlgError:
#    1083     # Testing for 0 variance doesn't catch all cases where scipy raises,
#    1084     # but we can also get a ValueError, so we need this convoluted approach
#    1085     singular = True
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/seaborn/_statistics.py:194, in KDE.__call__(self, x1, x2, weights)
#     192     return self._eval_univariate(x1, weights)
#     193 else:
# --> 194     return self._eval_bivariate(x1, x2, weights)
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/seaborn/_statistics.py:185, in KDE._eval_bivariate(self, x1, x2, weights)
#     182 else:
#     184     xx1, xx2 = np.meshgrid(*support)
# --> 185     density = kde([xx1.ravel(), xx2.ravel()]).reshape(xx1.shape)
#     187 return density, support
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/scipy/stats/_kde.py:253, in gaussian_kde.evaluate(self, points)
#     250 else:
#     251     raise TypeError('%s has unexpected item size %d' %
#     252                     (output_dtype, itemsize))
# --> 253 result = gaussian_kernel_estimate[spec](self.dataset.T, self.weights[:, None],
#     254                                         points.T, self.inv_cov, output_dtype)
#     255 return result[:, 0]
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f4556f1ca60> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/pyplot.py:137, in install_repl_displayhook.<locals>.post_execute()
#     135 def post_execute():
#     136     if matplotlib.is_interactive():
# --> 137         draw_all()
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py:141, in Gcf.draw_all(cls, force)
#     139 for manager in cls.get_all_fig_managers():
#     140     if force or manager.canvas.figure.stale:
# --> 141         manager.canvas.draw_idle()
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/backend_bases.py:2060, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2058 if not self._is_idle_drawing:
#    2059     with self._idle_draw_cntx():
# -> 2060         self.draw(*args, **kwargs)
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/figure.py:2845, in Figure.draw(self, renderer)
#    2842         # ValueError can occur when resizing a window.
#    2844 self.patch.draw(renderer)
# -> 2845 mimage._draw_list_compositing_images(
#    2846     renderer, self, artists, self.suppressComposite)
#    2848 for sfig in self.subfigs:
#    2849     sfig.draw(renderer)
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/text.py:729, in Text.draw(self, renderer)
#     726     textrenderer = renderer
#     728 if self.get_usetex():
# --> 729     textrenderer.draw_tex(gc, x, y, clean_line,
#     730                           self._fontproperties, angle,
#     731                           mtext=mtext)
#     732 else:
#     733     textrenderer.draw_text(gc, x, y, clean_line,
#     734                            self._fontproperties, angle,
#     735                            ismath=ismath, mtext=mtext)
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:285, in RendererAgg.draw_tex(self, gc, x, y, s, prop, angle, mtext)
#     281 size = prop.get_size_in_points()
#     283 texmanager = self.get_texmanager()
# --> 285 Z = texmanager.get_grey(s, size, self.dpi)
#     286 Z = np.array(Z * 255.0, np.uint8)
#     288 w, h, d = self.get_text_width_height_descent(s, prop, ismath="TeX")
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/texmanager.py:310, in TexManager.get_grey(self, tex, fontsize, dpi)
#     308 alpha = self._grey_arrayd.get(key)
#     309 if alpha is None:
# --> 310     pngfile = self.make_png(tex, fontsize, dpi)
#     311     rgba = mpl.image.imread(os.path.join(self.texcache, pngfile))
#     312     self._grey_arrayd[key] = alpha = rgba[:, :, -1]
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/texmanager.py:298, in TexManager.make_png(self, tex, fontsize, dpi)
#     295     if (getattr(mpl, "_called_from_pytest", False)
#     296             and mpl._get_executable_info("dvipng").version != bad_ver):
#     297         cmd.insert(1, "--freetype0")
# --> 298     self._run_checked_subprocess(cmd, tex)
#     299 return pngfile
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/matplotlib/texmanager.py:233, in TexManager._run_checked_subprocess(self, command, tex, cwd)
#     231 _log.debug(cbook._pformat_subprocess(command))
#     232 try:
# --> 233     report = subprocess.check_output(
#     234         command, cwd=cwd if cwd is not None else self.texcache,
#     235         stderr=subprocess.STDOUT)
#     236 except FileNotFoundError as exc:
#     237     raise RuntimeError(
#     238         'Failed to process string with tex because {} could not be '
#     239         'found'.format(command[0])) from exc
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/subprocess.py:415, in check_output(timeout, *popenargs, **kwargs)
#     412         empty = b''
#     413     kwargs['input'] = empty
# --> 415 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416            **kwargs).stdout
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/subprocess.py:493, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     490     kwargs['stdout'] = PIPE
#     491     kwargs['stderr'] = PIPE
# --> 493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
#     495         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/subprocess.py:858, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     854         if self.text_mode:
#     855             self.stderr = io.TextIOWrapper(self.stderr,
#     856                     encoding=encoding, errors=errors)
# --> 858     self._execute_child(args, executable, preexec_fn, close_fds,
#     859                         pass_fds, cwd, env,
#     860                         startupinfo, creationflags, shell,
#     861                         p2cread, p2cwrite,
#     862                         c2pread, c2pwrite,
#     863                         errread, errwrite,
#     864                         restore_signals, start_new_session)
#     865 except:
#     866     # Cleanup if the child failed starting.
#     867     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/subprocess.py:1655, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1653     fds_to_keep = set(pass_fds)
#    1654     fds_to_keep.add(errpipe_write)
# -> 1655     self.pid = _posixsubprocess.fork_exec(
#    1656             args, executable_list,
#    1657             close_fds, tuple(sorted(map(int, fds_to_keep))),
#    1658             cwd, env_list,
#    1659             p2cread, p2cwrite, c2pread, c2pwrite,
#    1660             errread, errwrite,
#    1661             errpipe_read, errpipe_write,
#    1662             restore_signals, start_new_session, preexec_fn)
#    1663     self._child_created = True
#    1664 finally:
#    1665     # be sure the FD is closed no matter what
#
# KeyboardInterrupt:

# %%
for pop in pops: 
    
    pop_key = 'pop '+pop
    
    plt.figure()

    for seed in seeds: 
        data = data_dict[pop_key][seed]
        
        plt.hist(data['logL'], bins=20, density=True, alpha=0.4)

# %%
for pop in pops: 
    
    pop_key = 'pop '+pop
    
    plt.figure()

    for seed in seeds: 
        data = data_dict[pop_key][seed]
        
        plt.scatter(data['logL'], data['Neff'])

# %%
for pop in pops: 
    
    pop_key = 'pop '+pop
    
    plt.figure()

    for seed in seeds: 
        data = data_dict[pop_key][seed]
        
        plt.scatter(data['logL'], data['minNsamps'])

# %% [markdown]
# Finally, let's make a "trace plot" showing the set of $\chi$ and $\cos \theta$ distributions corresponding to the above samples:

# %%
# Define a grid of effective spins
chi_grid = np.linspace(0,1,1000)
cost_grid = np.linspace(-1,1,1000)
chieff_grid = np.linspace(-0.6,0.6,1000)

# Choose a number of traces to draw
nTracesMax = 1000

for pop in pops: 
    
    # Set up fig and axes
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,3.75))
    
    for seed in seeds: 
            
        # Fetch data
        pop_key = 'pop '+pop
        data = data_dict[pop_key][seed]
        
        # plotting kws 
        kws = dict(color=colors_dict[seed], zorder=1)
        
        # Instantiate an array to hold a collection of traces
        nTraces = min(nTracesMax, len(data['mu_chi']['processed']))
        p_chi = np.zeros((nTraces,chi_grid.size))
        p_cost = np.zeros((nTraces,cost_grid.size))
        p_chieff = np.zeros((nTraces,chieff_grid.size))

        # For a random set of posterior samples, compute and store the corresponding probability densities across our grid
        random_indices = np.random.choice(np.arange(len(data['mu_chi']['processed'])), size=nTraces,replace=False)
        for i,ind in enumerate(random_indices):

            mu_chi = data['mu_chi']['processed'][ind]
            sigma_chi = data['sigma_chi']['processed'][ind]
            mu1_cost = data['mu1_cost']['processed'][ind]
            sigma1_cost = data['sigma1_cost']['processed'][ind]
            mu2_cost = data['mu2_cost']['processed'][ind]
            sigma2_cost = data['sigma2_cost']['processed'][ind]
            MF_cost = data['MF_cost']['processed'][ind]
            Bq = data['Bq']['processed'][ind]

            # calculate beta distribution for chi
            a,b = mu_sigma2_to_a_b(mu_chi, sigma_chi**2)
            p_chi[i,:] = calculate_betaDistribution(chi_grid, a, b)

            # and gaussian distribution for cos(theta)
            p_cost[i,:] = calculate_Double_Gaussian(cost_grid, mu1_cost, sigma1_cost, mu2_cost, sigma2_cost, MF_cost, -1, 1)   
            
            # inferred chi-eff distribution
            chi_effs = draw_chiEffs_and_chiPs_betaDoubleGauss(mu_chi, sigma_chi, mu1_cost, sigma1_cost, mu2_cost, sigma2_cost, MF_cost, Bq, n=1000)[0]
            chieff_kde = gaussian_kde(chi_effs)
            p_chieff[i,:] = chieff_kde(chieff_grid)

        # Plot 5% and 95% credible bounds
        axes[0].plot(chi_grid, np.quantile(p_chi,0.05,axis=0), **kws, label=f'seed={seed}')
        axes[0].plot(chi_grid, np.quantile(p_chi,0.95,axis=0), **kws)
        axes[1].plot(cost_grid, np.quantile(p_cost,0.05,axis=0), **kws)
        axes[1].plot(cost_grid, np.quantile(p_cost,0.95,axis=0), **kws)
        axes[2].plot(chieff_grid, np.quantile(p_chieff,0.05,axis=0), **kws)
        axes[2].plot(chieff_grid, np.quantile(p_chieff,0.95,axis=0), **kws)
        
        # Fill between 
        axes[0].fill_between(chi_grid, *np.quantile(p_chi,[0.05, 0.95],axis=0), **kws, alpha=0.1)
        axes[1].fill_between(cost_grid, *np.quantile(p_cost,[0.05, 0.95],axis=0), **kws, alpha=0.1)
        axes[2].fill_between(chieff_grid, *np.quantile(p_chieff,[0.05, 0.95],axis=0), **kws, alpha=0.1)
        
    # Plot true distributions distributions 
    mu_chi_true = hyperparams[pop][0]
    sigma_chi_true = hyperparams[pop][1]
    a_true, b_true = mu_sigma2_to_a_b(mu_chi_true, sigma_chi_true**2)
    p_chi_true = calculate_betaDistribution(chi_grid, a_true, b_true)
    mu1_cost_true =  hyperparams[pop][2]
    sigma1_cost_true = hyperparams[pop][3]
    mu2_cost_true =  hyperparams[pop][4]
    sigma2_cost_true = hyperparams[pop][5]
    MF_cost_true = hyperparams[pop][6]
    Bq_true = hyperparams[pop][7]
    p_cost_true = calculate_Double_Gaussian(cost_grid, mu1_cost_true, sigma1_cost_true, mu2_cost_true, sigma2_cost_true, MF_cost_true, -1, 1)
    axes[0].plot(chi_grid, p_chi_true, color='k', ls='--', zorder=2, label='truth')
    axes[1].plot(cost_grid, p_cost_true ,color='k', ls='--', zorder=2)
    
    chi_effs_true = draw_chiEffs_and_chiPs_betaDoubleGauss(mu_chi_true, sigma_chi_true, mu1_cost_true, 
                                                           sigma1_cost_true, mu2_cost_true, sigma2_cost_true, 
                                                           MF_cost_true, Bq_true, mCut=8, n=1000)[0]
    
    p_chieff_true = calculate_Gaussian_1D(chieff_grid, 0.11, 0.11, -1, 1)
    axes[2].plot(chieff_grid, p_chieff_true, color='k', ls='--', zorder=2)

    axes[0].set_xlim(0,1)
    axes[0].set_ylim(0,)
    axes[0].set_xlabel(r'$\chi$',fontsize=18)
    axes[0].set_ylabel(r'$p(\chi)$',fontsize=18)
    legend_loc = 'upper left' if pop=='1' else 'upper right'
    ncols = 2 if pop=='1' else 1
    axes[0].legend(loc=legend_loc, ncol=ncols)

    axes[1].set_xlim(-1,1)
    axes[1].set_ylim(0,)
    axes[1].set_xlabel(r'$\cos \theta$',fontsize=18)
    axes[1].set_ylabel(r'$p(\cos \theta)$',fontsize=18)
    
    axes[2].set_xlim(-0.5,0.5)
    axes[2].set_ylim(0,12)
    axes[2].set_xlabel(r'$\chi_\mathrm{eff}$',fontsize=18)
    axes[2].set_ylabel(r'$p(\chi_\mathrm{eff})$',fontsize=18)

    plt.suptitle(r'$\texttt{beta+doubleGaussian}$ ' +population_labels_dict[pop_key], fontsize=14)

    plt.show()
